# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshikaleves/AI-ML/blob/main/linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df= pd.read_csv('/content/homeprices.csv')
df.head()
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000

# %%
df.dropna(inplace=True)
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
reg = lm.LinearRegression()
reg.fit(df[['area','bedrooms','age']], df['price'])
# Out:
# LinearRegression()

# %%
reg.coef_.round(2)
# Out:
# array([  108.84, 26014.71, -2977.49])

# %%
reg.intercept_.round(2)
# Out:
# 218391.99

# %%
new_data = pd.DataFrame({'area': [2600], 'bedrooms': [3], 'age': [20]})
reg.predict(new_data )
# Out:
# array([519866.710013])
