# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshikaleves/AI-ML/blob/main/logistic_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# step 1 clean data set
# step 2 make model
# step 3 model fit and predict salary based on vairable

# %%
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegressionCV
from sklearn.metrics import accuracy_score

# %%
df =pd.read_csv('/content/insurance_data.csv')
df.head(5)
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
x = df[['age']]
y= df['bought_insurance']

# %%
import sklearn
from sklearn.model_selection import train_test_split

# %%
x_train, x_test , y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=10)

# %%
# @title Default title text
x_train
# Out:
#     age
# 2    47
# 12   27
# 24   50
# 14   49
# 13   29
# 20   21
# 3    52
# 25   54
# 6    55
# 19   18
# 10   18
# 23   45
# 26   23
# 8    62
# 22   40
# 16   25
# 17   58
# 0    22
# 15   55
# 4    46
# 9    61

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
x_test
# Out:
#     age
# 7    60
# 5    56
# 18   19
# 21   26
# 11   28
# 1    25

# %%
predictions = model.predict(x_test)
print(predictions)
# Out:
# [1 1 1 1 1 0]

# %%
y_test
# Out:
# 18    12800
# 1     34000
# 19    28200
# 8     12000
# Name: Sell Price($), dtype: int64

# %%
model.score(x_test, y_test)*100
# Out:
# 95.24414164762769

# %%
from sys import platlibdir
import matplotlib.pyplot as plt

plt.scatter(df['Age(yrs)'], df['Mileage'])
plt.xlabel('Age(yrs)')
plt.ylabel('Mileage')
plt.title('Age vs Mileage')
plt.show()
platlibdir
